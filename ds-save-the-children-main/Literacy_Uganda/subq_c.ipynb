# %% [markdown]
# ## Q: For attendance as a predictor, what is the minimum level for achieving expected outcome of reading with comprehension?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', 50)

# %%
df = pd.read_csv('data/merged_Uganda.csv', usecols=['ChildrenId', 'Baseline to Endline', 'AttendanceRate', 'ResultBaseline','ResultEndline']).drop_duplicates()
df
# Out:
#       ChildrenId ResultBaseline             ResultEndline Baseline to Endline  \
# 0          36161           Word  Story with comprehension            Increase
# 1          31440         Letter  Story with comprehension            Increase
# 2          36143           Word  Story with comprehension            Increase
# 3          36132           Word  Story with comprehension            Increase
# 4          31423         Letter  Story with comprehension            Increase
# ...          ...            ...                       ...                 ...
# 8974       38674         Letter                      Word            Increase
# 8975       38540       Beginner                      Word            Increase
# 8976       35469       Beginner                      Word            Increase
# 8977       38534           Word                      Word     Stayed The Same
# 8978       38602         Letter                      Word            Increase
#
#       AttendanceRate
# 0               0.80
# 1               0.00
# 2               0.00
# 3               1.00
# 4               0.00
# ...              ...
# 8974            0.75
# 8975            1.00
# 8976            0.25
# 8977            1.00
# 8978            1.00
#
# [8742 rows x 5 columns]

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='ResultEndline', y='AttendanceRate')

# Add titles and labels
plt.title('Attendance Rate VS ResultEndline')
plt.xlabel('Baseline to Endline Progress')
plt.ylabel('Attendance Rate')

plt.show()

# %%
df_filtered = df[df['ResultEndline'] == 'Story with comprehension']

# Plot attendance rates for each baseline-to-endline transition
plt.figure(figsize=(10, 6))
sns.boxplot(data=df_filtered, x='Baseline to Endline', y='AttendanceRate')

# Add titles and labels
plt.title('Attendance Rate Required for Achieving "Reading with Comprehension"')
plt.xlabel('Baseline to Endline Progress')
plt.ylabel('Attendance Rate')

plt.show()
